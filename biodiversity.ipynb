# %% [markdown]
# # Capstone 2: Biodiversity Project

# %% [markdown]
# # Introduction
# You are a biodiversity analyst working for the National Parks Service.  You're going to help them analyze some data about species at various national parks.
#
# Note: The data that you'll be working with for this project is *inspired* by real data, but is mostly fictional.

# %% [markdown]
# # Step 1
# Import the modules that you'll be using in this assignment:
# - `from matplotlib import pyplot as plt`
# - `import pandas as pd`

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Step 2
# You have been given two CSV files. `species_info.csv` with data about different species in our National Parks, including:
# - The scientific name of each species
# - The common names of each species
# - The species conservation status
#
# Load the dataset and inspect it:
# - Load `species_info.csv` into a DataFrame called `species`

# %%
species = pd.read_csv('species_info.csv')

# %% [markdown]
# Inspect each DataFrame using `.head()`.

# %%
species.head(10)
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
# 5   Mammal         Odocoileus virginianus
# 6   Mammal                     Sus scrofa
# 7   Mammal                  Canis latrans
# 8   Mammal                    Canis lupus
# 9   Mammal                    Canis rufus
#
#                                         common_names conservation_status
# 0                           Gapper's Red-Backed Vole                 NaN
# 1                              American Bison, Bison                 NaN
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...                 NaN
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)                 NaN
# 4                                      Wapiti Or Elk                 NaN
# 5                                  White-Tailed Deer                 NaN
# 6                                Feral Hog, Wild Pig                 NaN
# 7                                             Coyote  Species of Concern
# 8                                          Gray Wolf          Endangered
# 9                                           Red Wolf          Endangered

# %% [markdown]
# # Step 3
# Let's start by learning a bit more about our data.  Answer each of the following questions.

# %% [markdown]
# How many different species are in the `species` DataFrame?

# %%
print(len(species))
print(species.scientific_name.nunique())
# Out:
# 5824
# 5541

# %%
species[species.duplicated(['scientific_name'], keep='first')]
# Out:
#             category                   scientific_name  \
# 3017          Mammal                    Cervus elaphus
# 3019          Mammal            Odocoileus virginianus
# 3020          Mammal                       Canis lupus
# 3022          Mammal                     Puma concolor
# 3025          Mammal                  Lutra canadensis
# 3028          Mammal                     Mustela vison
# 3030          Mammal                     Procyon lotor
# 3031          Mammal                  Ursus americanus
# 3035          Mammal                  Eptesicus fuscus
# 3037          Mammal         Lasionycteris noctivagans
# 3038          Mammal                 Lasiurus cinereus
# 3042          Mammal                  Myotis lucifugus
# 3050          Mammal                 Castor canadensis
# 3056          Mammal                Ondatra zibethicus
# 3057          Mammal            Peromyscus maniculatus
# 3071          Mammal                    Sorex cinereus
# 3072          Mammal                        Sorex hoyi
# 3075          Mammal                   Sorex palustris
# 3081            Bird                 Pandion haliaetus
# 3088            Bird                   Branta bernicla
# 3091            Bird                 Chen caerulescens
# 3138            Bird                     Columba livia
# 3140            Bird             Streptopelia decaocto
# 3144            Bird                  Alectoris chukar
# 3150            Bird                       Gavia immer
# 3169            Bird                 Passerella iliaca
# 3184            Bird          Petrochelidon pyrrhonota
# 3185            Bird                   Riparia riparia
# 3191            Bird            Dumetella carolinensis
# 3192            Bird                 Mimus polyglottos
# ...              ...                               ...
# 5310  Vascular Plant                Digitalis purpurea
# 5312  Vascular Plant                 Gratiola neglecta
# 5325  Vascular Plant       Veronica anagallis-aquatica
# 5328  Vascular Plant                  Veronica persica
# 5367  Vascular Plant                      Salix exigua
# 5395  Vascular Plant                   Rotala ramosior
# 5416  Vascular Plant  Epilobium ciliatum ssp. ciliatum
# 5432  Vascular Plant                Ludwigia palustris
# 5438  Vascular Plant                Oxalis corniculata
# 5457  Vascular Plant            Bulbostylis capillaris
# 5504  Vascular Plant                Cyperus esculentus
# 5536  Vascular Plant                     Juncus tenuis
# 5553  Vascular Plant               Agrostis capillaris
# 5554  Vascular Plant                 Agrostis gigantea
# 5556  Vascular Plant                   Agrostis scabra
# 5557  Vascular Plant               Agrostis variabilis
# 5570  Vascular Plant                  Bromus secalinus
# 5576  Vascular Plant                  Cynodon dactylon
# 5580  Vascular Plant               Digitaria ischaemum
# 5581  Vascular Plant             Digitaria sanguinalis
# 5592  Vascular Plant            Eragrostis cilianensis
# 5597  Vascular Plant                     Festuca rubra
# 5600  Vascular Plant                    Holcus lanatus
# 5617  Vascular Plant            Muhlenbergia schreberi
# 5618  Vascular Plant                 Panicum miliaceum
# 5619  Vascular Plant  Panicum rigidulum var. rigidulum
# 5638  Vascular Plant                    Setaria pumila
# 5640  Vascular Plant                  Vulpia bromoides
# 5643  Vascular Plant                     Vulpia myuros
# 5750  Vascular Plant                   Rosa eglanteria
#
#                                            common_names conservation_status
# 3017                                 Rocky Mountain Elk                 NaN
# 3019               White-Tailed Deer, White-Tailed Deer                 NaN
# 3020                                    Gray Wolf, Wolf         In Recovery
# 3022                        Cougar, Mountain Lion, Puma                 NaN
# 3025                                        River Otter                 NaN
# 3028                                American Mink, Mink                 NaN
# 3030          Common Raccoon, Northern Raccoon, Raccoon                 NaN
# 3031                    American Black Bear, Black Bear                 NaN
# 3035                       Big Brown Bat, Big Brown Bat  Species of Concern
# 3037               Silver-Haired Bat, Silver-Haired Bat  Species of Concern
# 3038                               Hoary Bat, Hoary Bat                 NaN
# 3042  Little Brown Bat, Little Brown Myotis, Little ...  Species of Concern
# 3050                                    American Beaver                 NaN
# 3056                Common Muskrat, Muskbeaver, Muskrat                 NaN
# 3057               Deer Mouse, North American Deermouse                 NaN
# 3071         Cinereus Shrew, Common Shrew, Masked Shrew                 NaN
# 3072                  American Pygmy Shrew, Pygmy Shrew                 NaN
# 3075  American Water Shrew, Northern Water Shrew, Wa...                 NaN
# 3081                             Osprey, Western Osprey  Species of Concern
# 3088                    Brant, Brant Goose, Brent Goose                 NaN
# 3091                             Blue Goose, Snow Goose                 NaN
# 3138              Common Pigeon, Rock Dove, Rock Pigeon                 NaN
# 3140     Eurasian Collared Dove, Eurasian Collared-Dove                 NaN
# 3144                           Chukar, Chukar Partridge                 NaN
# 3150  Common Loon, Great Northern Diver, Great North...  Species of Concern
# 3169                       Fox Sparrow, Red Fox Sparrow                 NaN
# 3184              American Cliff Swallow, Cliff Swallow                 NaN
# 3185                          Bank Swallow, Sand Martin  Species of Concern
# 3191                         Gray Catbird, Grey Catbird                 NaN
# 3192                               Northern Mockingbird                 NaN
# ...                                                 ...                 ...
# 5310                                    Purple Foxglove                 NaN
# 5312  Clammy Hedgehyssop, Clammy Hedge-Hyssop, Drug ...                 NaN
# 5325              Blue Water Speedwell, Water Speedwell                 NaN
# 5328  Bird-Eye Speedwell, Birdseye Speedwell, Persia...                 NaN
# 5367                               Narrow-Leaved Willow                 NaN
# 5395           Lowland Rotala, Lowland Toothcup, Rotala                 NaN
# 5416               Coast Willowweed, Fringed Willowherb                 NaN
# 5432               Marsh Primrose-Willow, Marsh Seedbox                 NaN
# 5438  Creeping Oxalis, Creeping Woodsorrel, 'Ihi, Ye...                 NaN
# 5457           Densetuft Hairsedge, Threadleaf Beakseed                 NaN
# 5504  Chufa Flatsedge, Yellow Nutgrass, Yellow Nutsedge                 NaN
# 5536  Field Rush, Path Rush, Poverty Rush, Slender R...                 NaN
# 5553                  Colonial Bent, Colonial Bentgrass                 NaN
# 5554                Black Bent, Redtop, Water Bentgrass                 NaN
# 5556           Rough Bent, Rough Bentgrass, Ticklegrass                 NaN
# 5557                Mountain Bentgrass, Mountain Redtop                 NaN
# 5570  Bromegrass, Cheat, Chess, Chess Brome, Rye Bro...                 NaN
# 5576  Bermudagrass, Chiendent Pied-De-Poule, Common ...                 NaN
# 5580  Small Crabgrass, Smooth Crab Grass, Smooth Cra...                 NaN
# 5581  Crabgrass, Hairy Crab Grass, Hairy Crabgrass, ...                 NaN
# 5592  Candy Grass, Lovegrass, Stink Grass, Stinkgras...                 NaN
# 5597                          Ravine Fescue, Red Fescue                 NaN
# 5600     Common Velvetgrass, Velvetgrass, Yorkshire Fog                 NaN
# 5617                       Nimblewill, Nimblewill Muhly                 NaN
# 5618  Blackseeded Proso Millet, Broomcorn Millet, Br...                 NaN
# 5619                  Redtop Panicgrass, Redtop Panicum                 NaN
# 5638  Cattail Grass, Yellow Bristle Grass, Yellow Br...                 NaN
# 5640  Brome Fescue, Brome Six-Weeks Grass, Desert Fe...                 NaN
# 5643  Foxtail Fescue, Rattail Fescue, Rat-Tail Fescu...                 NaN
# 5750                                    Sweetbriar Rose                 NaN
#
# [283 rows x 4 columns]

# %%
species[species.duplicated(['scientific_name'], keep='last')]
# Out:
#             category            scientific_name  \
# 4             Mammal             Cervus elaphus
# 5             Mammal     Odocoileus virginianus
# 6             Mammal                 Sus scrofa
# 8             Mammal                Canis lupus
# 10            Mammal   Urocyon cinereoargenteus
# 16            Mammal              Puma concolor
# 18            Mammal         Spilogale putorius
# 20            Mammal           Lutra canadensis
# 25            Mammal              Mustela vison
# 26            Mammal              Procyon lotor
# 27            Mammal           Ursus americanus
# 29            Mammal           Eptesicus fuscus
# 30            Mammal  Lasionycteris noctivagans
# 32            Mammal          Lasiurus cinereus
# 37            Mammal           Myotis lucifugus
# 42            Mammal       Didelphis virginiana
# 49            Mammal          Castor canadensis
# 57            Mammal         Ondatra zibethicus
# 62            Mammal     Peromyscus maniculatus
# 68            Mammal         Erethizon dorsatum
# 81            Mammal             Sorex cinereus
# 84            Mammal                 Sorex hoyi
# 86            Mammal            Sorex palustris
# 104             Bird          Pandion haliaetus
# 116             Bird            Branta bernicla
# 120             Bird          Chen caerulescens
# 156             Bird              Columba livia
# 167             Bird           Alectoris chukar
# 172             Bird                Gavia immer
# 206             Bird          Passerella iliaca
# ...              ...                        ...
# 3039          Mammal        Myotis californicus
# 3040          Mammal         Myotis ciliolabrum
# 3042          Mammal           Myotis lucifugus
# 3049          Mammal          Ochotona princeps
# 3050          Mammal          Castor canadensis
# 3052          Mammal       Microtus longicaudus
# 3070          Mammal            Tamias umbrinus
# 3073          Mammal           Sorex monticolus
# 3077            Bird      Streptopelia decaocto
# 3138            Bird              Columba livia
# 3140            Bird      Streptopelia decaocto
# 3145            Bird  Centrocercus urophasianus
# 3151            Bird             Gavia pacifica
# 3165            Bird              Pica hudsonia
# 3179            Bird    Leucosticte tephrocotis
# 3190            Bird           Lanius excubitor
# 3224            Bird        Contopus sordidulus
# 3228            Bird         Empidonax wrightii
# 3238            Bird           Melanerpes lewis
# 3246            Bird       Podiceps nigricollis
# 3251            Bird           Glaucidium gnoma
# 3254            Bird             Strix nebulosa
# 3255         Reptile             Charina bottae
# 3292  Vascular Plant                Lemna gibba
# 3437  Vascular Plant          Cirsium scariosum
# 3488  Vascular Plant       Hypochaeris radicata
# 3913  Vascular Plant     Utricularia intermedia
# 4008  Vascular Plant               Salix exigua
# 4184  Vascular Plant        Agrostis variabilis
# 4236  Vascular Plant             Holcus lanatus
#
#                                            common_names conservation_status
# 4                                         Wapiti Or Elk                 NaN
# 5                                     White-Tailed Deer                 NaN
# 6                                   Feral Hog, Wild Pig                 NaN
# 8                                             Gray Wolf          Endangered
# 10                            Common Gray Fox, Gray Fox                 NaN
# 16                              Panther (Mountain Lion)                 NaN
# 18                                Eastern Spotted Skunk                 NaN
# 20                                 Northern River Otter                 NaN
# 25                                                 Mink                 NaN
# 26                              Common Raccoon, Raccoon                 NaN
# 27                                           Black Bear                 NaN
# 29                                        Big Brown Bat  Species of Concern
# 30                                    Silver-Haired Bat  Species of Concern
# 32                                            Hoary Bat                 NaN
# 37                Little Brown Bat, Little Brown Myotis  Species of Concern
# 42                  Virginia Opossum, Virginia Oppossum                 NaN
# 49                              American Beaver, Beaver                 NaN
# 57                                              Muskrat                 NaN
# 62                                           Deer Mouse                 NaN
# 68                          Common Porcupine, Porcupine                 NaN
# 81                           Common Shrew, Masked Shrew                 NaN
# 84                                          Pygmy Shrew                 NaN
# 86                                          Water Shrew                 NaN
# 104                                              Osprey  Species of Concern
# 116                                               Brant                 NaN
# 120                                          Snow Goose                 NaN
# 156                                           Rock Dove                 NaN
# 167                                              Chukar                 NaN
# 172                                         Common Loon  Species of Concern
# 206                                         Fox Sparrow                 NaN
# ...                                                 ...                 ...
# 3039  California Myotis, California Myotis, Californ...  Species of Concern
# 3040  Small-Footed Myotis, Western Small-Footed Bat,...                 NaN
# 3042  Little Brown Bat, Little Brown Myotis, Little ...  Species of Concern
# 3049                                American Pika, Pika                 NaN
# 3050                                    American Beaver                 NaN
# 3052           Coronation Island Vole, Long-Tailed Vole                 NaN
# 3070                                     Uinta Chipmunk                 NaN
# 3073                                        Dusky Shrew                 NaN
# 3077                             Eurasian Collared-Dove                 NaN
# 3138              Common Pigeon, Rock Dove, Rock Pigeon                 NaN
# 3140     Eurasian Collared Dove, Eurasian Collared-Dove                 NaN
# 3145  Greater Sage Grouse, Greater Sage-Grouse, Sage...                 NaN
# 3151                        Pacific Diver, Pacific Loon                 NaN
# 3165                        Black-Billed Magpie, Magpie                 NaN
# 3179                            Gray-Crowned Rosy-Finch                 NaN
# 3190                 Great Grey Shrike, Northern Shrike                 NaN
# 3224             Western Wood Pewee, Western Wood-Pewee                 NaN
# 3228                   Gray Flycatcher, Grey Flycatcher                 NaN
# 3238              Lewis' Woodpecker, Lewis's Woodpecker                 NaN
# 3246                    Black-Necked Grebe, Eared Grebe                 NaN
# 3251             Mountain Pygmy Owl, Northern Pygmy-Owl                 NaN
# 3254                     Great Gray Owl, Great Grey Owl                 NaN
# 3255                                         Rubber Boa                 NaN
# 3292                                   Swollen Duckweed                 NaN
# 3437                                    Evert's Thistle                 NaN
# 3488          Spotted Cats-Ear, Hairy Cats-Ear, Gosmore                 NaN
# 3913                               Flatleaf Bladderwort                 NaN
# 4008  Coyote Willow, Desert Willow, Narrowleaf Willo...                 NaN
# 4184                                 Mountain Bentgrass                 NaN
# 4236                  Common Velvetgrass, Yorkshire-Fog                 NaN
#
# [283 rows x 4 columns]

# %% [markdown]
# What are the different values of `category` in `species`?

# %%
species.category.unique()
# Out:
# array(['Mammal', 'Bird', 'Reptile', 'Amphibian', 'Fish', 'Vascular Plant',
#        'Nonvascular Plant'], dtype=object)

# %% [markdown]
# What are the different values of `conservation_status`?

# %%
species.conservation_status.unique()
# Out:
# array([nan, 'Species of Concern', 'Endangered', 'Threatened',
#        'In Recovery'], dtype=object)

# %% [markdown]
# # Step 4
# Let's start doing some analysis!
#
# The column `conservation_status` has several possible values:
# - `Species of Concern`: declining or appear to be in need of conservation
# - `Threatened`: vulnerable to endangerment in the near future
# - `Endangered`: seriously at risk of extinction
# - `In Recovery`: formerly `Endangered`, but currnetly neither in danger of extinction throughout all or a significant portion of its range
#
# We'd like to count up how many species meet each of these criteria.  Use `groupby` to count how many `scientific_name` meet each of these criteria.

# %%
species.groupby('conservation_status').scientific_name.nunique().reset_index()
# Out:
#   conservation_status  scientific_name
# 0          Endangered               15
# 1         In Recovery                4
# 2  Species of Concern              151
# 3          Threatened               10

# %% [markdown]
# As we saw before, there are far more than 200 species in the `species` table.  Clearly, only a small number of them are categorized as needing some sort of protection.  The rest have `conservation_status` equal to `None`.  Because `groupby` does not include `None`, we will need to fill in the null values.  We can do this using `.fillna`.  We pass in however we want to fill in our `None` values as an argument.
#
# Paste the following code and run it to see replace `None` with `No Intervention`:
# ```python
# species.fillna('No Intervention', inplace=True)
# ```

# %%
species.fillna('No Intervention', inplace=True)

# %% [markdown]
# Great! Now run the same `groupby` as before to see how many species require `No Protection`.

# %%
species.groupby('conservation_status').scientific_name.nunique()
# Out:
# conservation_status
# Endangered              15
# In Recovery              4
# No Intervention       5363
# Species of Concern     151
# Threatened              10
# Name: scientific_name, dtype: int64

# %% [markdown]
# Let's use `plt.bar` to create a bar chart.  First, let's sort the columns by how many species are in each categories.  We can do this using `.sort_values`.  We use the the keyword `by` to indicate which column we want to sort by.
#
# Paste the following code and run it to create a new DataFrame called `protection_counts`, which is sorted by `scientific_name`:
# ```python
# protection_counts = species.groupby('conservation_status')\
#     .scientific_name.count().reset_index()\
#     .sort_values(by='scientific_name')
# ```

# %%
protection_counts = species.groupby('conservation_status')\
    .scientific_name.count().reset_index()\
    .sort_values(by='scientific_name')
protection_counts
# Out:
#   conservation_status  scientific_name
# 1         In Recovery                4
# 4          Threatened               10
# 0          Endangered               16
# 3  Species of Concern              161
# 2     No Intervention             5633

# %% [markdown]
# Now let's create a bar chart!
# 1. Start by creating a wide figure with `figsize=(10, 4)`
# 1. Start by creating an axes object called `ax` using `plt.subplot`.
# 2. Create a bar chart whose heights are equal to `scientific_name` column of `protection_counts`.
# 3. Create an x-tick for each of the bars.
# 4. Label each x-tick with the label from `conservation_status` in `protection_counts`
# 5. Label the y-axis `Number of Species`
# 6. Title the graph `Conservation Status by Species`
# 7. Plot the grap using `plt.show()`

# %%
# %matplotlib inline
plt.figure(figsize=(10, 4))
ax = plt.subplot()
x_vals = range(len(protection_counts))
plt.bar(x_vals, protection_counts.scientific_name, color='C1', alpha=0.6)
ax.set_xticks(x_vals)
ax.set_xticklabels(protection_counts.conservation_status)
plt.ylabel('Number of Species')
plt.title('Conservation Status')
plt.grid(axis='y', linestyle='--', alpha=0.8)
plt.savefig('Conservation_Status.png');

# %% [markdown]
# # Step 4
# Are certain types of species more likely to be endangered?

# %% [markdown]
# Let's create a new column in `species` called `is_protected`, which is `True` if `conservation_status` is not equal to `No Intervention`, and `False` otherwise.

# %%
species['is_protected'] = species.conservation_status.apply(lambda x: x != 'No Intervention')
species.head()
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
#
#                                         common_names conservation_status  \
# 0                           Gapper's Red-Backed Vole     No Intervention
# 1                              American Bison, Bison     No Intervention
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...     No Intervention
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)     No Intervention
# 4                                      Wapiti Or Elk     No Intervention
#
#    is_protected
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %% [markdown]
# Let's group by *both* `category` and `is_protected`.  Save your results to `category_counts`.

# %%
category_counts = species.groupby(['category', 'is_protected']).scientific_name.nunique().reset_index()

# %% [markdown]
# Examine `category_count` using `head()`.

# %%
category_counts.head()
# Out:
#     category  is_protected  scientific_name
# 0  Amphibian         False               72
# 1  Amphibian          True                7
# 2       Bird         False              413
# 3       Bird          True               75
# 4       Fish         False              115

# %% [markdown]
# It's going to be easier to view this data if we pivot it.  Using `pivot`, rearange `category_counts` so that:
# - `columns` is `conservation_status`
# - `index` is `category`
# - `values` is `scientific_name`
#
# Save your pivoted data to `category_pivot`. Remember to `reset_index()` at the end.

# %%
category_pivot = category_counts.pivot(columns='is_protected', index='category', values='scientific_name').reset_index()

# %% [markdown]
# Examine `category_pivot`.

# %%
category_pivot
# Out:
# is_protected           category  False  True
# 0                     Amphibian     72     7
# 1                          Bird    413    75
# 2                          Fish    115    11
# 3                        Mammal    146    30
# 4             Nonvascular Plant    328     5
# 5                       Reptile     73     5
# 6                Vascular Plant   4216    46

# %% [markdown]
# Use the `.columns` property to  rename the categories `True` and `False` to something more description:
# - Leave `category` as `category`
# - Rename `False` to `not_protected`
# - Rename `True` to `protected`

# %%
category_pivot.columns = ['category', 'not_protected', 'protected']
category_pivot
# Out:
#             category  not_protected  protected
# 0          Amphibian             72          7
# 1               Bird            413         75
# 2               Fish            115         11
# 3             Mammal            146         30
# 4  Nonvascular Plant            328          5
# 5            Reptile             73          5
# 6     Vascular Plant           4216         46

# %% [markdown]
# Let's create a new column of `category_pivot` called `percent_protected`, which is equal to `protected` (the number of species that are protected) divided by `protected` plus `not_protected` (the total number of species).

# %%
category_pivot['percent_protected'] = category_pivot.apply(lambda row: '{0:.2%}'.format(row.protected/float(row.not_protected + row.protected)), axis=1)

# %% [markdown]
# Examine `category_pivot`.

# %%
category_pivot
# Out:
#             category  not_protected  protected percent_protected
# 0          Amphibian             72          7             8.86%
# 1               Bird            413         75            15.37%
# 2               Fish            115         11             8.73%
# 3             Mammal            146         30            17.05%
# 4  Nonvascular Plant            328          5             1.50%
# 5            Reptile             73          5             6.41%
# 6     Vascular Plant           4216         46             1.08%

# %% [markdown]
# It looks like species in category `Mammal` are more likely to be endangered than species in `Bird`.  We're going to do a significance test to see if this statement is true.  Before you do the significance test, consider the following questions:
# - Is the data numerical or categorical?
# - How many pieces of data are you comparing?

# %% [markdown]
# Based on those answers, you should choose to do a *chi squared test*.  In order to run a chi squared test, we'll need to create a contingency table.  Our contingency table should look like this:
#
# ||protected|not protected|
# |-|-|-|
# |Mammal|?|?|
# |Bird|?|?|
#
# Create a table called `contingency` and fill it in with the correct numbers

# %%
i = (3, 1)
c = (2, 1)
contingency = category_pivot.values[i, ][:, c ]
contingency
# Out:
# array([[30L, 146L],
#        [75L, 413L]], dtype=object)

# %% [markdown]
# In order to perform our chi square test, we'll need to import the correct function from scipy.  Past the following code and run it:
# ```py
# from scipy.stats import chi2_contingency
# ```

# %%
from scipy.stats import chi2_contingency

# %% [markdown]
# Now run `chi2_contingency` with `contingency`.

# %%
chi2, pval, _, _ = chi2_contingency(contingency)
print(pval)
# Out:
# 0.6875948096661336

# %% [markdown]
# It looks like this difference isn't significant!
#
# Let's test another.  Is the difference between `Reptile` and `Mammal` significant?

# %%
i = (3, 5)
c = (2, 1)
contingency2 = category_pivot.values[i, ][:, c ]
chi22, pval2, _, _ = chi2_contingency(contingency2)
print(pval2)
# Out:
# 0.03835559022969898

# %% [markdown]
# Yes! It looks like there is a significant difference between `Reptile` and `Mammal`!

# %% [markdown]
# # Step 5

# %% [markdown]
# Conservationists have been recording sightings of different species at several national parks for the past 7 days.  They've saved sent you their observations in a file called `observations.csv`.  Load `observations.csv` into a variable called `observations`, then use `head` to view the data.

# %%
observations = pd.read_csv('observations.csv')
observations.head()
# Out:
#             scientific_name                            park_name  observations
# 0        Vicia benghalensis  Great Smoky Mountains National Park            68
# 1            Neovison vison  Great Smoky Mountains National Park            77
# 2         Prunus subcordata               Yosemite National Park           138
# 3      Abutilon theophrasti                  Bryce National Park            84
# 4  Githopsis specularioides  Great Smoky Mountains National Park            85

# %% [markdown]
# Some scientists are studying the number of sheep sightings at different national parks.  There are several different scientific names for different types of sheep.  We'd like to know which rows of `species` are referring to sheep.  Notice that the following code will tell us whether or not a word occurs in a string:

# %%
# Does "Sheep" occur in this string?
str1 = 'This string contains Sheep'
'Sheep' in str1
# Out:
# True

# %%
# Does "Sheep" occur in this string?
str2 = 'This string contains Cows'
'Sheep' in str2
# Out:
# False

# %% [markdown]
# Use `apply` and a `lambda` function to create a new column in `species` called `is_sheep` which is `True` if the `common_names` contains `'Sheep'`, and `False` otherwise.

# %%
species['is_sheep'] = species.apply(lambda row: 'Sheep' in row.common_names, axis=1)

# %% [markdown]
# Select the rows of `species` where `is_sheep` is `True` and examine the results.

# %%
species[species.is_sheep]
# Out:
#             category              scientific_name  \
# 3             Mammal                   Ovis aries
# 1139  Vascular Plant             Rumex acetosella
# 2233  Vascular Plant           Festuca filiformis
# 3014          Mammal              Ovis canadensis
# 3758  Vascular Plant             Rumex acetosella
# 3761  Vascular Plant            Rumex paucifolius
# 4091  Vascular Plant                 Carex illota
# 4383  Vascular Plant  Potentilla ovina var. ovina
# 4446          Mammal      Ovis canadensis sierrae
#
#                                            common_names conservation_status  \
# 3     Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)     No Intervention
# 1139                        Sheep Sorrel, Sheep Sorrell     No Intervention
# 2233                              Fineleaf Sheep Fescue     No Intervention
# 3014                       Bighorn Sheep, Bighorn Sheep  Species of Concern
# 3758  Common Sheep Sorrel, Field Sorrel, Red Sorrel,...     No Intervention
# 3761   Alpine Sheep Sorrel, Fewleaved Dock, Meadow Dock     No Intervention
# 4091                       Sheep Sedge, Smallhead Sedge     No Intervention
# 4383                                   Sheep Cinquefoil     No Intervention
# 4446                        Sierra Nevada Bighorn Sheep          Endangered
#
#       is_protected  is_sheep
# 3            False      True
# 1139         False      True
# 2233         False      True
# 3014          True      True
# 3758         False      True
# 3761         False      True
# 4091         False      True
# 4383         False      True
# 4446          True      True

# %% [markdown]
# Many of the results are actually plants.  Select the rows of `species` where `is_sheep` is `True` and `category` is `Mammal`.  Save the results to the variable `sheep_species`.

# %%
sheep_species = species[(species.is_sheep) & (species.category=='Mammal')]
sheep_species
# Out:
#      category          scientific_name  \
# 3      Mammal               Ovis aries
# 3014   Mammal          Ovis canadensis
# 4446   Mammal  Ovis canadensis sierrae
#
#                                            common_names conservation_status  \
# 3     Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)     No Intervention
# 3014                       Bighorn Sheep, Bighorn Sheep  Species of Concern
# 4446                        Sierra Nevada Bighorn Sheep          Endangered
#
#       is_protected  is_sheep
# 3            False      True
# 3014          True      True
# 4446          True      True

# %% [markdown]
# Now merge `sheep_species` with `observations` to get a DataFrame with observations of sheep.  Save this DataFrame as `sheep_observations`.

# %%
sheep_observations = pd.merge(sheep_species, observations)
sheep_observations
# Out:
#    category          scientific_name  \
# 0    Mammal               Ovis aries
# 1    Mammal               Ovis aries
# 2    Mammal               Ovis aries
# 3    Mammal               Ovis aries
# 4    Mammal          Ovis canadensis
# 5    Mammal          Ovis canadensis
# 6    Mammal          Ovis canadensis
# 7    Mammal          Ovis canadensis
# 8    Mammal  Ovis canadensis sierrae
# 9    Mammal  Ovis canadensis sierrae
# 10   Mammal  Ovis canadensis sierrae
# 11   Mammal  Ovis canadensis sierrae
#
#                                          common_names conservation_status  \
# 0   Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)     No Intervention
# 1   Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)     No Intervention
# 2   Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)     No Intervention
# 3   Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)     No Intervention
# 4                        Bighorn Sheep, Bighorn Sheep  Species of Concern
# 5                        Bighorn Sheep, Bighorn Sheep  Species of Concern
# 6                        Bighorn Sheep, Bighorn Sheep  Species of Concern
# 7                        Bighorn Sheep, Bighorn Sheep  Species of Concern
# 8                         Sierra Nevada Bighorn Sheep          Endangered
# 9                         Sierra Nevada Bighorn Sheep          Endangered
# 10                        Sierra Nevada Bighorn Sheep          Endangered
# 11                        Sierra Nevada Bighorn Sheep          Endangered
#
#     is_protected  is_sheep                            park_name  observations
# 0          False      True               Yosemite National Park           126
# 1          False      True  Great Smoky Mountains National Park            76
# 2          False      True                  Bryce National Park           119
# 3          False      True            Yellowstone National Park           221
# 4           True      True            Yellowstone National Park           219
# 5           True      True                  Bryce National Park           109
# 6           True      True               Yosemite National Park           117
# 7           True      True  Great Smoky Mountains National Park            48
# 8           True      True            Yellowstone National Park            67
# 9           True      True               Yosemite National Park            39
# 10          True      True                  Bryce National Park            22
# 11          True      True  Great Smoky Mountains National Park            25

# %% [markdown]
# How many total sheep observations (across all three species) were made at each national park?  Use `groupby` to get the `sum` of `observations` for each `park_name`.  Save your answer to `obs_by_park`.
#
# This is the total number of sheep observed in each park over the past 7 days.

# %%
obs_by_park = sheep_observations.groupby('park_name').observations.sum().reset_index()
obs_by_park
# Out:
#                              park_name  observations
# 0                  Bryce National Park           250
# 1  Great Smoky Mountains National Park           149
# 2            Yellowstone National Park           507
# 3               Yosemite National Park           282

# %% [markdown]
# Create a bar chart showing the different number of observations per week at each park.
#
# 1. Start by creating a wide figure with `figsize=(16, 4)`
# 1. Start by creating an axes object called `ax` using `plt.subplot`.
# 2. Create a bar chart whose heights are equal to `observations` column of `obs_by_park`.
# 3. Create an x-tick for each of the bars.
# 4. Label each x-tick with the label from `park_name` in `obs_by_park`
# 5. Label the y-axis `Number of Observations`
# 6. Title the graph `Observations of Sheep per Week`
# 7. Plot the grap using `plt.show()`

# %%
plt.figure(figsize=(16, 4))
ax = plt.subplot()
x_vals = range(len(obs_by_park))
plt.bar(x_vals, obs_by_park.observations, color='C1', alpha=0.6)
ax.set_xticks(x_vals)
ax.set_xticklabels(obs_by_park.park_name)
plt.ylabel('Observations')
plt.title('Observations of Sheep per Week')
plt.grid(axis='y', linestyle='--', alpha=0.8)
plt.savefig('ObsSheepPerWeek.png');

# %% [markdown]
# Our scientists know that 15% of sheep at Bryce National Park have foot and mouth disease.  Park rangers at Yellowstone National Park have been running a program to reduce the rate of foot and mouth disease at that park.  The scientists want to test whether or not this program is working.  They want to be able to detect reductions of at least 5 percentage point.  For instance, if 10% of sheep in Yellowstone have foot and mouth disease, they'd like to be able to know this, with confidence.
#
# Use the sample size calculator at <a href="https://www.optimizely.com/sample-size-calculator/">Optimizely</a> to calculate the number of sheep that they would need to observe from each park.  Use the default level of significance (90%).
#
# Remember that "Minimum Detectable Effect" is a percent of the baseline.

# %%
min_detectable_effect = 100 * 0.05 / 0.15
min_detectable_effect
# Out:
# 33.333333333333336

# %% [markdown]
# How many weeks would you need to observe sheep at Bryce National Park in order to observe enough sheep?  How many weeks would you need to observe at Yellowstone National Park to observe enough sheep?

# %%
sample_size = 510.0
weeks_bc = sample_size/obs_by_park.values[0, 1]
weeks_ys = sample_size/obs_by_park.values[2, 1]
print(weeks_bc)
print(weeks_ys)
# Out:
# 2.04
# 1.00591715976
